# %% [markdown]
# # Analisis de Datos con Pandas y Matplotlib

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("hotel_bookings.csv")

# %%
dataset.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
#dimension de la tabla
dataset.shape
# Out:
# (119390, 32)

# %%
#columnas del dataset
dataset.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
#tipos de datos
#puede cambiarse
dataset.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %% [markdown]
# # Filtros

# %%
dataset['country'].unique()
# Out:
# array(['PRT', 'GBR', 'USA', 'ESP', 'IRL', 'FRA', nan, 'ROU', 'NOR', 'OMN',
#        'ARG', 'POL', 'DEU', 'BEL', 'CHE', 'CN', 'GRC', 'ITA', 'NLD',
#        'DNK', 'RUS', 'SWE', 'AUS', 'EST', 'CZE', 'BRA', 'FIN', 'MOZ',
#        'BWA', 'LUX', 'SVN', 'ALB', 'IND', 'CHN', 'MEX', 'MAR', 'UKR',
#        'SMR', 'LVA', 'PRI', 'SRB', 'CHL', 'AUT', 'BLR', 'LTU', 'TUR',
#        'ZAF', 'AGO', 'ISR', 'CYM', 'ZMB', 'CPV', 'ZWE', 'DZA', 'KOR',
#        'CRI', 'HUN', 'ARE', 'TUN', 'JAM', 'HRV', 'HKG', 'IRN', 'GEO',
#        'AND', 'GIB', 'URY', 'JEY', 'CAF', 'CYP', 'COL', 'GGY', 'KWT',
#        'NGA', 'MDV', 'VEN', 'SVK', 'FJI', 'KAZ', 'PAK', 'IDN', 'LBN',
#        'PHL', 'SEN', 'SYC', 'AZE', 'BHR', 'NZL', 'THA', 'DOM', 'MKD',
#        'MYS', 'ARM', 'JPN', 'LKA', 'CUB', 'CMR', 'BIH', 'MUS', 'COM',
#        'SUR', 'UGA', 'BGR', 'CIV', 'JOR', 'SYR', 'SGP', 'BDI', 'SAU',
#        'VNM', 'PLW', 'QAT', 'EGY', 'PER', 'MLT', 'MWI', 'ECU', 'MDG',
# ...

# %%
dataset['country'].value_counts()
# Out:
# country
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: count, Length: 177, dtype: int64

# %%
dataset['country'].value_counts()/len(dataset)
# Out:
# country
# PRT    0.406986
# GBR    0.101591
# FRA    0.087235
# ESP    0.071765
# DEU    0.061035
#          ...
# DJI    0.000008
# BWA    0.000008
# HND    0.000008
# VGB    0.000008
# NAM    0.000008
# Name: count, Length: 177, dtype: float64

# %%
dataset['country'].isnull() # casos nulos
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 119385    False
# 119386    False
# 119387    False
# 119388    False
# 119389    False
# Name: country, Length: 119390, dtype: bool

# %%
dataset['country'].isnull().sum() ##cantidad total
# Out:
# 488

# %%
dataset['country'].isnull().mean() ##porcentaje total
# Out:
# 0.004087444509590418

# %%
dataset[~dataset['country'].isnull()] #casos no nulos
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
~dataset['country'].isnull()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 119385    True
# 119386    True
# 119387    True
# 119388    True
# 119389    True
# Name: country, Length: 119390, dtype: bool

# %%
dataset['country'].fillna('ESP')
# Out:
# 0         PRT
# 1         PRT
# 2         GBR
# 3         GBR
# 4         GBR
#          ...
# 119385    BEL
# 119386    FRA
# 119387    DEU
# 119388    GBR
# 119389    DEU
# Name: country, Length: 119390, dtype: object

# %%
#modificacion de nulos
dataset['country'].fillna('ESP')

# %%
#extraer faltantes de todas las columnas
columnas = dataset.columns

for col in columnas:
    tipo = dataset[col].dtype
    porcentjae_na=dataset[col].isnull().mean()
    
    if(porcentjae_na<=0.05):
        print(f"{col}: {porcentjae_na}")
        if(tipo=="object"):
            valor_inputar = dataset[col].mode()
        else:
            valor_inputar = dataset[col].mean()
            
        dataset[col].fillna(valor_inputar, inplace=True)
# Out:
# hotel: 0.0
# is_canceled: 0.0
# lead_time: 0.0
# arrival_date_year: 0.0
# arrival_date_month: 0.0
# arrival_date_week_number: 0.0
# arrival_date_day_of_month: 0.0
# stays_in_weekend_nights: 0.0
# stays_in_week_nights: 0.0
# adults: 0.0
# children: 3.350364352123293e-05
# babies: 0.0
# meal: 0.0
# country: 0.004087444509590418
# market_segment: 0.0
# distribution_channel: 0.0
# is_repeated_guest: 0.0
# previous_cancellations: 0.0
# previous_bookings_not_canceled: 0.0
# reserved_room_type: 0.0
# assigned_room_type: 0.0
# booking_changes: 0.0
# deposit_type: 0.0
# agent: 0.0
# days_in_waiting_list: 0.0
# customer_type: 0.0
# adr: 0.0
# required_car_parking_spaces: 0.0
# total_of_special_requests: 0.0
# reservation_status: 0.0
# reservation_status_date: 0.0

# %%
# rellenar con media columnas vacias
media = dataset["agent"].mean()

dataset["agent"].fillna(media, inplace=True)

# %%
dataset["agent"].dtype== "float64"
# Out:
# True

# %%
dataset[ (dataset["country"]=="FRA") & (dataset["children"]==0 ) & (dataset["babies"]==0) ]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 18      Resort Hotel            0          0               2015
# 80      Resort Hotel            0         99               2015
# 101     Resort Hotel            0         98               2015
# 127     Resort Hotel            0        100               2015
# 129     Resort Hotel            0        100               2015
# ...              ...          ...        ...                ...
# 119263    City Hotel            0        115               2017
# 119286    City Hotel            0        177               2017
# 119288    City Hotel            0         44               2017
# 119312    City Hotel            0          4               2017
# 119386    City Hotel            0        102               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 18                   July                        27
# 80                   July                        27
# ...

# %%
#personas que reservan en Francia o España y no reservaron con niños o bebes
dataset[ (dataset["country"].isin(["FRA","ESP"]) ) & (dataset["children"]==0 ) & (dataset["babies"]==0)  ]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 18      Resort Hotel            0          0               2015
# 36      Resort Hotel            0         15               2015
# 42      Resort Hotel            0         16               2015
# 46      Resort Hotel            0         96               2015
# 53      Resort Hotel            0          3               2015
# ...              ...          ...        ...                ...
# 119288    City Hotel            0         44               2017
# 119312    City Hotel            0          4               2017
# 119343    City Hotel            0        149               2017
# 119346    City Hotel            0         45               2017
# 119386    City Hotel            0        102               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 18                   July                        27
# 36                   July                        27
# ...

# %%
dataset["meal"].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC', 'Undefined'], dtype=object)

# %%
dataset["total_niños"] = dataset["children"] + dataset["babies"]
dataset[dataset["total_niños"]>0]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 13      Resort Hotel            0         18               2015
# 45      Resort Hotel            1         47               2015
# 55      Resort Hotel            0          1               2015
# 65      Resort Hotel            0         10               2015
# 87      Resort Hotel            1         79               2015
# ...              ...          ...        ...                ...
# 119270    City Hotel            0          0               2017
# 119287    City Hotel            0        167               2017
# 119293    City Hotel            0        243               2017
# 119318    City Hotel            0        160               2017
# 119319    City Hotel            0         45               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 13                   July                        27
# 45                   July                        27
# ...

# %%
nuevo = dataset[dataset["total_niños"]>0]
nuevo["meal"].value_counts(normalize =True)
# Out:
# meal
# BB           0.815553
# HB           0.148779
# SC           0.020566
# FB           0.008997
# Undefined    0.006105
# Name: proportion, dtype: float64

# %%
dataset["market_segment"].unique()
# Out:
# array(['Direct', 'Corporate', 'Online TA', 'Offline TA/TO',
#        'Complementary', 'Groups', 'Undefined', 'Aviation'], dtype=object)

# %%
#para el market_segment = Groups cual es el promedio de adultos por reserva?
ms_groups=dataset[dataset["market_segment"]=="Groups"]
ms_groups["adults"].mean()
# Out:
# 1.7968805209227197

# %%
dataset["days_in_waiting_list"]
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 119385    0
# 119386    0
# 119387    0
# 119388    0
# 119389    0
# Name: days_in_waiting_list, Length: 119390, dtype: int64

# %%
tmp = dataset[dataset["country"].isin(["PRT","GBR","FRA"])]

# %%
tmp["days_in_waiting_list"].max()
# Out:
# 391

# %%
tmp[tmp["country"]=="PRT"]["days_in_waiting_list"].mean()
# Out:
# 4.0540852027166085

# %%
tmp[tmp["country"]=="GBR"]["days_in_waiting_list"].mean()
# Out:
# 0.5231263912935938

# %%
tmp[tmp["country"]=="FRA"]["days_in_waiting_list"].mean()
# Out:
# 2.3092654824771963

# %% [markdown]
# ## Escala de variables

# %%
def get_Df_Variable_Scale_Type(dataset):

    continuas =[]
    discretas =[]
    categoricas =[]

    for col in dataset.columns:
        tipoDato= dataset[col].dtype
        if((tipoDato=="int64") or (tipoDato =="float64")):
            if(len(dataset[col].unique())>30):
                continuas.append(col)
            else:
                discretas.append(col)
        else:
            categoricas.append(col)
    
    return continuas, discretas, categoricas
    #tipoData = dataset["children"].dtype
    #len(dataset["children"].unique())

# %%
tipoData
# Out:
# dtype('float64')

# %%
categoricas
# Out:
# ['hotel',
#  'arrival_date_month',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'reserved_room_type',
#  'assigned_room_type',
#  'deposit_type',
#  'customer_type',
#  'reservation_status',
#  'reservation_status_date']

# %%
continuas
# Out:
# ['lead_time',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_week_nights',
#  'previous_bookings_not_canceled',
#  'agent',
#  'company',
#  'days_in_waiting_list',
#  'adr']

# %%
discretas
# Out:
# ['is_canceled',
#  'arrival_date_year',
#  'stays_in_weekend_nights',
#  'adults',
#  'children',
#  'babies',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'booking_changes',
#  'required_car_parking_spaces',
#  'total_of_special_requests',
#  'total_niños']

# %%
cont,discre, cate = get_Df_Variable_Scale_Type(dataset)

# %%
cont
# Out:
# ['lead_time',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_week_nights',
#  'previous_bookings_not_canceled',
#  'agent',
#  'company',
#  'days_in_waiting_list',
#  'adr']

# %%
discre
# Out:
# ['is_canceled',
#  'arrival_date_year',
#  'stays_in_weekend_nights',
#  'adults',
#  'children',
#  'babies',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'booking_changes',
#  'required_car_parking_spaces',
#  'total_of_special_requests',
#  'total_niños']

# %%
cate
# Out:
# ['hotel',
#  'arrival_date_month',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'reserved_room_type',
#  'assigned_room_type',
#  'deposit_type',
#  'customer_type',
#  'reservation_status',
#  'reservation_status_date']

# %%
dataset.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
dataset["lead_time"].describe()
# Out:
# count    119390.000000
# mean        104.011416
# std         106.863097
# min           0.000000
# 25%          18.000000
# 50%          69.000000
# 75%         160.000000
# max         737.000000
# Name: lead_time, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.displot(dataset, x="lead_time", kind="kde")
# Out:
# C:\Users\XPRS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
for col in continuas:
    estadisticios = dataset[col].describe()
    sns.displot(dataset, x=col, kind="kde")
    plt.show()
    print()
    print("------------------------------------------")
    print(col)
    print("------------------------------------------")
    print()
    print("Minimo:", estadisticios["min"])
    print("Maedia:", estadisticios["mean"])
    print("Mediana:", estadisticios["50%"])
    print("maximo:", estadisticios["max"])
    print("Desviacion:", estadisticios["std"])
    print("Varianza:", estadisticios["std"]**2)
    print("------------------------------------------")
    print()
# Out:
# C:\Users\XPRS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ------------------------------------------
# lead_time
# ------------------------------------------
#
# Minimo: 0.0
# Maedia: 104.01141636652986
# Mediana: 69.0
# maximo: 737.0
# Desviacion: 106.86309704798579
# Varianza: 11419.72151068723
# ------------------------------------------
# C:\Users\XPRS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ------------------------------------------
# arrival_date_week_number
# ------------------------------------------
#
# Minimo: 1.0
# Maedia: 27.16517296255968
# Mediana: 28.0
# maximo: 53.0
# Desviacion: 13.605138355498454
# Varianza: 185.09978967225518
# ------------------------------------------
# ...

# %% [markdown]
# ## Agregacion

# %%
dataset["hotel"].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
dataset.groupby("hotel").sum()
# Out:
#               is_canceled  lead_time  arrival_date_year  \
# hotel
# City Hotel          33102    8705335          159943106
# Resort Hotel        11122    3712588           80765825
#
#                                              arrival_date_month  \
# hotel
# City Hotel    JulyJulyJulyJulyJulyJulyJulyJulyJulyJulyJulyJu...
# Resort Hotel  JulyJulyJulyJulyJulyJulyJulyJulyJulyJulyJulyJu...
#
#               arrival_date_week_number  arrival_date_day_of_month  \
# hotel
# City Hotel                     2155987                    1252353
# Resort Hotel                   1087263                     633799
#
#               stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# hotel
# City Hotel                      63082                173174  146838    7248.0
# Resort Hotel                    47664                125337   74798    5155.0
#
#               ...                                       deposit_type  \
# hotel         ...
# ...

# %%
dataset.groupby(["hotel","meal"]).agg(
    media_adultos=("adults", "sum"),
    media_children =("children", "mean")
)
# Out:
#                         media_adultos  media_children
# hotel        meal
# City Hotel   BB                114987        0.104573
#              FB                    53        0.000000
#              HB                 12227        0.086177
#              SC                 19571        0.017039
# Resort Hotel BB                 55293        0.127279
#              FB                  1510        0.103448
#              HB                 15729        0.148397
#              SC                   134        0.081395
#              Undefined           2132        0.048760
